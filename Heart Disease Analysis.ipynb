# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# target   -0.225439 -0.280937  0.433798 -0.144931 -0.085239 -0.028046
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.116211 -0.398522  0.096801  0.210013 -0.168814  0.276326
# sex      -0.058196 -0.044020  0.141664  0.096093 -0.030711  0.118261
# cp        0.044421  0.295762 -0.394280 -0.149230  0.119717 -0.181053
# trestbps -0.114103 -0.046698  0.067616  0.193216 -0.121475  0.101389
# chol     -0.151040 -0.009940  0.067023  0.053952 -0.004038  0.070511
# fbs      -0.084189 -0.008567  0.025665  0.005747 -0.059894  0.137979
# restecg   1.000000  0.044123 -0.070733 -0.058770  0.093045 -0.072042
# thalach   0.044123  1.000000 -0.378812 -0.344187  0.386784 -0.213177
# exang    -0.070733 -0.378812  1.000000  0.288223 -0.257748  0.115739
# oldpeak  -0.058770 -0.344187  0.288223  1.000000 -0.577537  0.222682
# slope     0.093045  0.386784 -0.257748 -0.577537  1.000000 -0.080155
# ca       -0.072042 -0.213177  0.115739  0.222682 -0.080155  1.000000
# thal     -0.011981 -0.096439  0.206754  0.210244 -0.104764  0.151832
# target    0.137230  0.421741 -0.436757 -0.430696  0.345877 -0.391724
#
#               thal    target
# age       0.068001 -0.225439
# sex       0.210041 -0.280937
# cp       -0.161736  0.433798
# trestbps  0.062210 -0.144931
# chol      0.098803 -0.085239
# fbs      -0.032019 -0.028046
# restecg  -0.011981  0.137230
# thalach  -0.096439  0.421741
# exang     0.206754 -0.436757
# oldpeak   0.210244 -0.430696
# slope    -0.104764  0.345877
# ca        0.151832 -0.391724
# thal      1.000000 -0.344029
# target   -0.344029  1.000000

# %%
over_50 = heart_disease [heart_disease['age'] > 50]
over_50.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.133583  0.008420  0.127710  0.084153 -0.045450
# sex      -0.133583  1.000000 -0.054336 -0.100805 -0.270769  0.050687
# cp        0.008420 -0.054336  1.000000  0.075210 -0.033332  0.153275
# trestbps  0.127710 -0.100805  0.075210  1.000000  0.047469  0.174268
# chol      0.084153 -0.270769 -0.033332  0.047469  1.000000 -0.054718
# fbs      -0.045450  0.050687  0.153275  0.174268 -0.054718  1.000000
# restecg  -0.040443 -0.060153 -0.064740 -0.089979 -0.136856 -0.071680
# thalach  -0.216317 -0.078136  0.273793  0.043005  0.089841  0.066605
# exang    -0.053743  0.187189 -0.427533 -0.000872  0.019952 -0.041345
# oldpeak   0.075093  0.107889 -0.179429  0.144408  0.014080 -0.036838
# slope    -0.084737 -0.090386  0.131244 -0.096307  0.023030 -0.026272
# ca        0.186036  0.104284 -0.263057  0.004727  0.049612  0.064444
# thal     -0.007886  0.201043 -0.153308  0.051711  0.094938 -0.122345
# target   -0.093215 -0.269037  0.464090 -0.114232 -0.036867  0.035454
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.040443 -0.216317 -0.053743  0.075093 -0.084737  0.186036
# sex      -0.060153 -0.078136  0.187189  0.107889 -0.090386  0.104284
# cp       -0.064740  0.273793 -0.427533 -0.179429  0.131244 -0.263057
# trestbps -0.089979  0.043005 -0.000872  0.144408 -0.096307  0.004727
# chol     -0.136856  0.089841  0.019952  0.014080  0.023030  0.049612
# fbs      -0.071680  0.066605 -0.041345 -0.036838 -0.026272  0.064444
# restecg   1.000000 -0.037232  0.032363 -0.050885  0.104500 -0.041627
# thalach  -0.037232  1.000000 -0.328606 -0.295314  0.375975 -0.148905
# exang     0.032363 -0.328606  1.000000  0.233980 -0.203741  0.074573
# oldpeak  -0.050885 -0.295314  0.233980  1.000000 -0.575503  0.267666
# slope     0.104500  0.375975 -0.203741 -0.575503  1.000000 -0.085783
# ca       -0.041627 -0.148905  0.074573  0.267666 -0.085783  1.000000
# thal      0.036833 -0.033958  0.182101  0.205256 -0.078519  0.137190
# target    0.079807  0.319457 -0.420059 -0.410962  0.331749 -0.408163
#
#               thal    target
# age      -0.007886 -0.093215
# sex       0.201043 -0.269037
# cp       -0.153308  0.464090
# trestbps  0.051711 -0.114232
# chol      0.094938 -0.036867
# fbs      -0.122345  0.035454
# restecg   0.036833  0.079807
# thalach  -0.033958  0.319457
# exang     0.182101 -0.420059
# oldpeak   0.205256 -0.410962
# slope    -0.078519  0.331749
# ca        0.137190 -0.408163
# thal      1.000000 -0.268744
# target   -0.268744  1.000000

# %%
plt.style.use('seaborn-whitegrid')
fig, (ax0,ax1) = plt.subplots(nrows=2,
                            ncols=1,
                            figsize=(10,10),
                             sharex=True);

scatter = ax0.scatter(x=over_50['cp'],
                     y=over_50['slope'],
                     c=over_50['target'],
                     cmap='winter')

ax0.set (title = 'Heart Disease and Choleterol level',
        ylabel = 'cholesterol')

ax0.set_xlim([50 , 80])

ax0.legend(*scatter.legend_elements() , title='Target')

ax0.axhline(y=over_50['chol'].mean(),
               linestyle = '--');


scatter = ax1.scatter(x=over_50['age'],
                     y=over_50['thalach'],
                     c=over_50['target'],
                     cmap='winter')

ax1.set (title = 'Heart Disease and Max Heart rate',
           xlabel = 'age',
           ylabel = 'heart rate')

ax1.set_xlim([50 , 80])
ax1.set_ylim([60 , 200])

ax1.legend(*scatter.legend_elements() , title='Target')

ax1.axhline(y=over_50['thalach'].mean(),
               linestyle = '--');

fig.suptitle('Heart Disease Analysis', fontsize=17 ,fontstyle='oblique');
